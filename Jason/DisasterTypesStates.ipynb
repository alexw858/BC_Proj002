# %%
import pandas as pd
import numpy as np

# %%
disaster_summary = 'top_10_disaster.csv'
disaster_df = pd.read_csv(disaster_summary)

# %%
disaster_df.head()
# Out:
#    disasterNumber                 State  \
# 0            1809              Missouri
# 1            1756              Oklahoma
# 2            3300  District of Columbia
# 3            4134              Colorado
# 4            3366         West Virginia
#
#                                      Title   FederalFunded   ProjectAmount
# 0   SEVERE STORMS, FLOODING, AND A TORNADO   $8,529,243.13     11356158.47
# 1   SEVERE STORMS, TORNADOES, AND FLOODING   $2,229,174.06      2852298.38
# 2           56TH PRESIDENTIAL INAUGURATION   $9,540,583.88      9540583.88
# 3                    BLACK FOREST WILDFIRE   $6,617,742.08      8818357.72
# 4                           CHEMICAL SPILL   $1,639,099.39      2178019.05

# %%
for index, row in disaster_df.iterrows():
# Out:
#  SEVERE STORMS, FLOODING, AND A TORNADO
#  SEVERE STORMS, TORNADOES, AND FLOODING
# 56TH PRESIDENTIAL INAUGURATION
# BLACK FOREST WILDFIRE
# CHEMICAL SPILL
# EARTHQUAKE
# EARTHQUAKE
# EARTHQUAKE
# EARTHQUAKE
# EARTHQUAKE,TSUNAMI, AND FLOODING
# EXPLOSION
# EXPLOSION
# EXPLOSIONS
# EXPLOSIONS AND FIRE
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING
# FLOODING AND ICE JAMS
# FLOODING AND MUDSLIDES
# FLOODING, LANDSLIDES, AND MUDSLIDES
# FLOODING, LANDSLIDES, AND MUDSLIDES
# HIGH PARK AND WALDO CANYON WILDFIRES
# HURRICANE ALEX
# HURRICANE DOLLY
# HURRICANE EARL
# HURRICANE EARL
# HURRICANE EARL
# HURRICANE GUSTAV
# HURRICANE GUSTAV
# HURRICANE GUSTAV
# HURRICANE GUSTAV
# HURRICANE GUSTAV
# HURRICANE GUSTAV
# ...

# %%
# Out:
# 3258
